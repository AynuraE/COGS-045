# %% [markdown]
# Learn to predict the next character in the works of William Shakespeare, and use the acquired model to generate samples of Shakespeare-like text.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
import numpy as np
#try to use a GPU, if it's available, for faster training. may not be.
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#make sure you have the Shakespeare.txt file somewhere accessible. You can upload it using the functionality on the left <----

#alternative
# from google.colab import drive
# drive.mount('/content/drive/MyDrive/Shakespeare.txt')

data_path = ('/content/Shakespeare.txt')

#if you have trouble with the data path. use the command "pwd" (present working directory) to see where you are, and make sure the path makes sense, given that location.
#you can find the file on the left and click "copy path"

# %%
#we use a version of an RNN called a "Long-Short Term Memory".
#Like a simple RNN, an LSTM processes sequences of data, and continually uses the previous hidden state activitations to causally influence the activities at each subsequent "timestep" in the sequence.

#but, unlike a simple RNN, it additionally has "gating" parameters that allow the information-flow to be dynamically modified. In most cases, it performs better than a simple RNN.

class LSTM(nn.Module):
    def __init__(self, input_size, output_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        self.embedding = nn.Embedding(input_size, input_size)
        self.rnn = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers)
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, input_seq, hidden_state):
        embedding = self.embedding(input_seq)
        output, hidden_state = self.rnn(embedding, hidden_state)
        output = self.decoder(output)
        return output, (hidden_state[0].detach(), hidden_state[1].detach())

# %%
#features of the model that you could modify, if you wished.

hidden_size = 512   # size of hidden state
seq_len = 100       # length of LSTM sequence
num_layers = 3      # num of layers in LSTM
lr = 0.002          # learning rate; how big of a step to take in gradient descent
epochs = 500        # max number of epochs
op_seq_len = 100    # total num of characters in output test sequence
load_chk = False   # load weights from save_path directory to continue training

#where the model should be saved (or already was saved, if you are re-running)
# from google.colab import drive
# drive.mount('/content/drive/MyDrive/Shakespeare.txt')
#save_path = "/content/drive/MyDrive/CharRNN_Shakespeare"

# %%
# load the text file
data = open(data_path, 'r').read()
chars = sorted(list(set(data)))
data_size, vocab_size = len(data), len(chars)
print("----------------------------------------")
print("Data has {} characters, {} unique".format(data_size, vocab_size))
print("----------------------------------------")
# Out:
# ----------------------------------------
# Data has 1115395 characters, 65 unique
# ----------------------------------------

# %%
# char to index and index to char maps
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# convert data from characters to indices
data = list(data)
for i, ch in enumerate(data):
    data[i] = char_to_ix[ch]

# data tensor on device
data = torch.tensor(data).to(device)
data = torch.unsqueeze(data, dim=1)

#################################

# %%
# model
rnn = LSTM(vocab_size, vocab_size, hidden_size, num_layers).to(device)

# if you already ran the model and saved the progress, you can re-load it here.
if load_chk:
    rnn.load_state_dict(torch.load(save_path))
    print("Model loaded successfully !!")
    print("----------------------------------------")

# loss function and optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rnn.parameters(), lr=lr)

# %%
# main training loop for recurrent neural network
for i_epoch in range(1, epochs+1):
    sample_n = 0
    # random starting point
    data_ptr = np.random.randint(100)
    n = 0
    running_loss = 0
    hidden_state = None

    while True:
      #given one character as input,
        input_seq = data[data_ptr : data_ptr+seq_len]
      #predict the next character in the sequence
        target_seq = data[data_ptr+1 : data_ptr+seq_len+1]

      # forward pass through neural network to generate each prediction
        output, hidden_state = rnn(input_seq, hidden_state)

    ##### the loss is the difference between the predicted next character and the true next character.###
        loss = loss_fn(torch.squeeze(output), torch.squeeze(target_seq))
        running_loss += loss.item()

    #compute gradients and backprop error
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    #update the data pointer (Where in sequence are we?)
        data_ptr += seq_len
        n +=1

    #if at end of data : break
        if data_ptr + seq_len + 1 > data_size:
            break

        if n % 100 ==0:
          sample_n+=1

    ###### generate some text, occasionally
          data_ptr_test = 0
          hidden_state = None

      #random character from data to begin generating a sample
          rand_index = np.random.randint(data_size-1)
          input_seq = data[rand_index : rand_index+1]

          print("----------------------------------------")
          print("Sample Number: {0} \t Loss: {1:.8f}".format(sample_n, running_loss/n))
          while True:
          # forward pass
              output, hidden_state = rnn(input_seq, hidden_state)

          #sample a character
              output = F.softmax(torch.squeeze(output), dim=0)
              dist = Categorical(output)
              index = dist.sample()

          # print the sampled character
              print(ix_to_char[index.item()], end='')

          # next input is current output
              input_seq[0][0] = index.item()
              data_ptr_test += 1

              if data_ptr_test > op_seq_len:
                  break
          print("----------------------------------------")

# print loss and save weights after every epoch
    print("Epoch: {0} \t Loss: {1:.8f}".format(i_epoch, running_loss/n))
    torch.save(rnn.state_dict(), save_path)
# Out:
# ----------------------------------------
# Sample Number: 1 	 Loss: 3.13666896
# WfXQTotCeebict tedd crene, yhee !ererirsl sao yiy'n tat tewmd ikt ipnd parg vobll
# sH
# MI hob aana!'org----------------------------------------
# ----------------------------------------
# Sample Number: 2 	 Loss: 2.82630540
# AnlA;.
#
# VAuAGavh when Aore yerd toud im. I our add.
#
# EARFId.
#
# SILInGIIre ene ,oer I tis, yof yoae.
#
# V----------------------------------------
# ----------------------------------------
# Sample Number: 3 	 Loss: 2.62629260
# $BKKGXRXs I frawers nolmyy there at you ceut. -wliasd she musre,
# PIRLIUS:
# Seted soug, thut'ch sotum-t----------------------------------------
# ----------------------------------------
# Sample Number: 4 	 Loss: 2.50180378
# wesb: toars
# go enito the
# brattrs beet, out perkhed, the fortner yow besuotias
# suserins:
# if than anin ----------------------------------------
# ----------------------------------------
# Sample Number: 5 	 Loss: 2.40797401
# ZGejXjab at lissey, by blice, wery hhan out Tro', that but as dlive oud lakug, Ond
# Sohices
# Poiper
# He ----------------------------------------
# ----------------------------------------
# Sample Number: 6 	 Loss: 2.31863646
# -Yools bastilg: and utastuet
# were wourdt I blive citine not the wive mathler
# he
# the froocuiuting his?----------------------------------------
# ----------------------------------------
# Sample Number: 7 	 Loss: 2.23786931
# be go no them his ake by sone-flatens cron shilet asered viton.
#
# CORIOLANUS:
# Here sturres: them winll----------------------------------------
# ----------------------------------------
# Sample Number: 8 	 Loss: 2.17979114
# uNfwich the fore grar pobits!
#
# Citizen:
# Be comn nattorpur
# You you ameard not
# Got the wan ren of gown ----------------------------------------
# ----------------------------------------
# Sample Number: 9 	 Loss: 2.12924787
# Tell's
# As canveriwiton torgechood wort
# As flom him smake. How, am the presg, of a dirm
# Throu nod soar----------------------------------------
# ----------------------------------------
# Sample Number: 10 	 Loss: 2.08444690
# !
#
# CORIOLANUS:
# Shithen:
# By shake avme gome geatl.
#
# SICINIUS:
# Let me common.
# ',
# Stall with he sech owe----------------------------------------
# ----------------------------------------
# Sample Number: 11 	 Loss: 2.04550610
# ;-
# Cain:
# Eivices if
# Thou him to nov giv w ow'd wurnow of thy thue
# A countive to dome for
# Do weeelour ----------------------------------------
# ----------------------------------------
# Sample Number: 12 	 Loss: 2.01049065
# P$aignOqJqz.
# !o't tarlitihius! trierlys:
# are Malcius worgh torganed o' the shill'd.
#
# AUFINIUS:
# Swith ----------------------------------------
# ----------------------------------------
# Sample Number: 13 	 Loss: 1.97977935
# uef him.
#
# COMINIUS:
# To hand fe husgon I thof hear his died to his blood contitbers.
# Who af naid afden----------------------------------------
# ----------------------------------------
# Sample Number: 14 	 Loss: 1.95775737
# eot. Hould 'bother my senh yous wurcent Rome unYour sleats my naw in thus stand and since to hear usa----------------------------------------
# ----------------------------------------
# Sample Number: 15 	 Loss: 1.93626339
# H?
#
# Bessenger:
# If Rome his heod Wife, 'Rour him:
# Thry him nesitce!
#
# VARFIUS:
# Who. O have let unmess.
# ----------------------------------------
# ----------------------------------------
# Sample Number: 16 	 Loss: 1.92356344
# rom have as geitay; as with scond
# That beard! gridence, his bange abpests helchince, Come
# Being these----------------------------------------
# ----------------------------------------
# Sample Number: 17 	 Loss: 1.90564034
# ther spat curse my salt world pairony's wear they were those beanty lead.
#
# GLOUCESTER:
# Nath.
#
# LADY AN----------------------------------------
# ----------------------------------------
# Sample Number: 18 	 Loss: 1.89112866
# I:
# By they where, binesr. God-steetfter jlaf, a king in, must lond,--
#
# SLOUCESTER:
# The enerance of Gl----------------------------------------
# ----------------------------------------
# Sample Number: 19 	 Loss: 1.87464279
# l in liise th
# y me,
# And vouch do hate is with me sword thy leach.
#
# BUCKINGHAM:
# I I my forgagers,
# Yout----------------------------------------
# ----------------------------------------
# Sample Number: 20 	 Loss: 1.85874126
# ,
# And Goman the tofn; oaloud virtence that a lanch
# Mudderer wrong, enenow haks his are reason for an ----------------------------------------
# ----------------------------------------
# Sample Number: 21 	 Loss: 1.84308534
#
# For I snawal, kill itder me to samer. For he, alviegn greed onder peace!
#
# IUTGS:
# This windingeaut, t----------------------------------------
# ----------------------------------------
# Sample Number: 22 	 Loss: 1.82942385
# !
#
# ThrUCKHETH:
# First Constions;
# A Toul duft, recutings heart.
#
# BUCKIE
# SWoulth God's grild.
# Comin fort----------------------------------------
# ----------------------------------------
# Sample Number: 23 	 Loss: 1.81224147
# me as for the hog
# Thut then, my faar live, cousin me
# What I mise I thinks Vore lift preid on this tlo----------------------------------------
# ----------------------------------------
# Sample Number: 24 	 Loss: 1.79803601
#
# Then  in fear rake he nobl decame,
# I'll command prosed are see The breefings, and son, Greough,
# We p----------------------------------------
# ----------------------------------------
# Sample Number: 25 	 Loss: 1.78627800
#
# When fook his hair these, which, Bay,
# Fistinged wI are present we did fact!
# Mamy the trestly hell:
# I----------------------------------------
# ----------------------------------------
# Sample Number: 26 	 Loss: 1.77536606
# ent.
#
# BUCKINGHAM:
# The deit mighty and death inf'll,
# That good no grace: then.
#
# BUCKINGHAM:
# Do the cut----------------------------------------
# ----------------------------------------
# Sample Number: 27 	 Loss: 1.76486805
# e redrent.
#
# KY CRELL:
# They blood: and is moy;
# Give they is life to meet;
# Seps thy initissy poor bleas----------------------------------------
# ----------------------------------------
# Sample Number: 28 	 Loss: 1.75668575
# y
# As thou werting them and queen therees belief my time;
# As dispeefy lord of a pray,
# Their careedinge----------------------------------------
# ----------------------------------------
# Sample Number: 29 	 Loss: 1.74261304
# Rish not
# Canst all thy daughter and she Untessed to her loth,
# Eus king an happinaless.
#
# KING RICHARD ----------------------------------------
# ----------------------------------------
# Sample Number: 30 	 Loss: 1.73173336
#
# What Yorksh to good mamer king, wheroods in mades beseech-diven bave,
# What salimed friends and adfel----------------------------------------
# ----------------------------------------
# Sample Number: 31 	 Loss: 1.72676313
# rings, , why the done to-morrow?
# What, by royal darqummchance, and early mayy trustate?
#
# Ghost night ----------------------------------------
# ----------------------------------------
# Sample Number: 32 	 Loss: 1.72040183
# vy my Lorny,
# Lives my arm with this speak the dain of warm,
# Him, Elizahity, succeps to thee;
# Wherefor----------------------------------------
# ----------------------------------------
# Sample Number: 33 	 Loss: 1.71473066
# woundress from ancomes
# Y appercuot of your highness with shall be yet were age.
#
# Your orfolcome lefve----------------------------------------
# ----------------------------------------
# Sample Number: 34 	 Loss: 1.70695617
# But know pray his with the light dind on thy Dorsek welcome.
#
# JOHN OF AUMERDY
#
# KING RICHARD II:
# but n----------------------------------------
# ----------------------------------------
# Sample Number: 35 	 Loss: 1.70208667
# s,
# That saedle wont this sword, for his pastants,
# Are spirond manishmen youth are dearises ouf stadms----------------------------------------
# ----------------------------------------
# Sample Number: 36 	 Loss: 1.69643576
# Zers;
# Be the more, a beless of this our weeps,
# How is rugs gentle both, may will, dear
# But distrint t----------------------------------------
# ----------------------------------------
# Sample Number: 37 	 Loss: 1.69033138
#
# Harry, most your to three would gentlemen.
#
# HENRY PERCY:
# And noble form-bope the mnicate.
#
# BUSHY MEr----------------------------------------
# ----------------------------------------
# Sample Number: 38 	 Loss: 1.68409092
# Kisble monearth,
# We knowing of triestaun-trseachery, art,
#
#  our business and storm:
# More forth men, l----------------------------------------
# ----------------------------------------
# Sample Number: 39 	 Loss: 1.67815083
# ble but despair
# To
# Yread to breed the confind fartherhough.
#
# HENRY KERLENY:
# Sleich a made, by upon bu----------------------------------------
# ----------------------------------------
# Sample Number: 40 	 Loss: 1.67299300
# orse;
# But licure the hand my spries should be not on terplle, be it thee.
#
# QUEEN:
# Till our burden, in----------------------------------------
# ----------------------------------------
# Sample Number: 41 	 Loss: 1.66763092
# ged.
#
# LORD FITZWOP:
# Is thy hour's cagot here gloriof and Surrey,
# The field this steel that throw, Ano----------------------------------------
# ----------------------------------------
# Sample Number: 42 	 Loss: 1.66211434
# ive,
# There is stricker him form, but uncle;
# That, in a full the holy Ever deliver'd
# Till with did sha----------------------------------------
# ----------------------------------------
# Sample Number: 43 	 Loss: 1.65523568
# ome your cre:
# Hath let me as may old boys of on thee,
# Adpant, to pardon the grue womanreason the gray----------------------------------------
# ----------------------------------------
# Sample Number: 44 	 Loss: 1.65094293
# whost. I will pardon outer, haw taes time the death
# Groous king'd let a marreal and among
# Sirs wone t----------------------------------------
# ----------------------------------------
# Sample Number: 45 	 Loss: 1.64899850
# Ns up my mordeff,
# Sir?
# Drefwend me up the best?
#
# TYAY:
# Vew his sceptiel you my seen?
# Towards and yiel----------------------------------------
# ----------------------------------------
# Sample Number: 46 	 Loss: 1.64849338
# l!
#
# RYuo:
# Fo are is herself bright all more; I will tell my owx.
#
# Servant:
# So mourn some days of an w----------------------------------------
# ----------------------------------------
# Sample Number: 47 	 Loss: 1.64767230
# bed hazer,
# Exhonoureth, learn, helps of the consorlich, I too, a dies lust were follook' see:
# Repole ----------------------------------------
# ----------------------------------------
# Sample Number: 48 	 Loss: 1.64481399
# ight like of wundous weme;
# With mersefage that threat of my master are.
# I, chonoung this is thege wea----------------------------------------
# ----------------------------------------
# Sample Number: 49 	 Loss: 1.64139334
# y,
# Toward's groan bonish dagbes help!
#
# JULIET:
# For I send mine again, how I win.
# Twatter are is duse,----------------------------------------
# ----------------------------------------
# Sample Number: 50 	 Loss: 1.64015012
# ? a deeds marry old Ejer?
# Pactle: deared, hide thy what is
# his man
# for straint as it
# good nomps and q----------------------------------------
# ----------------------------------------
# Sample Number: 51 	 Loss: 1.63697291
# 3got came: quort for thou have two
# As thou happy streeting deat
# That sly brout us doance: thou
# hart
# W----------------------------------------
# ----------------------------------------
# Sample Number: 52 	 Loss: 1.63448167
# you badiseds thee,
# For mine mad, for ushang thy some eagor, be?
#
# Nurse:
# Come, 'freay I nirs,
# Welr'd m----------------------------------------
# ----------------------------------------
# Sample Number: 53 	 Loss: 1.63143433
# raw
# Moury ler, of so smile out perfessiesoiner so
# do sents dry lay:
# And, no prince
# Fire she--which no----------------------------------------
# ----------------------------------------
# Sample Number: 54 	 Loss: 1.62759243
# Ping is not; nerge!
#
# ROMEO:
# O, it dranner at not in.
#
# JULIET:
# A love?' now, and sir she,
# Sk shall not----------------------------------------
# ----------------------------------------
# Sample Number: 55 	 Loss: 1.62373206
# ord him;
# To shall have the hints? bether I with, Juliet,
# Boy jeshaphed got die by able strong death,
# ----------------------------------------
# ----------------------------------------
# Sample Number: 56 	 Loss: 1.62175512
# ndminate
# Upon you dift mosin prost-hast!
# Hateful many kiss of a face!
#
# CETER:
# Heaven I seovened to-ni----------------------------------------
# ----------------------------------------
# Sample Number: 57 	 Loss: 1.61928184
# :
# Come, they is are my palous by, and give me quarrs,
# Now shall sleepy tooishes of you!
#
# FRIAR LAUREN----------------------------------------
# ----------------------------------------
# Sample Number: 58 	 Loss: 1.61599762
# and, flet the Laurtous.
#
# Second Wake Borators,
# Dare I that's no blow them, Were sceal gound.
# Come of ----------------------------------------
# ----------------------------------------
# Sample Number: 59 	 Loss: 1.61048815
# villapal,
# O, my deshruch into poison me.
#
# MARTAGWARET:
# 'Proud thee to the frection of bints.
#
# JULIET:----------------------------------------
# ----------------------------------------
# Sample Number: 60 	 Loss: 1.60784789
# ny:
# Aftrose' is the sifk upon trament
# That Rooper'd my Alhise, with the swree:
# Where is must muty you----------------------------------------
# ----------------------------------------
# Sample Number: 61 	 Loss: 1.60597063
# harge,--
#
# RICHARD:
# By death 'Dokes these very and by mine upes the can that is them,
# And flower igles----------------------------------------
# ----------------------------------------
# Sample Number: 62 	 Loss: 1.60214112
# n the fortune.
#
# CLIFFORD:'
# Alour fast, I quickly us't is sod,
# Stay slience and on his sword.
#
# Myself:----------------------------------------
# ----------------------------------------
# Sample Number: 63 	 Loss: 1.59964342
# ery grief gond
# So for you conqueerated comment of rient-hearted rise delivance.
#
# That would I take th----------------------------------------
# ----------------------------------------
# Sample Number: 64 	 Loss: 1.59635180
# es,
# Should an wakd can you to with ree bounds are though 'He will;
# Now nor in thee Acquerable quorein----------------------------------------
# ----------------------------------------
# Sample Number: 65 	 Loss: 1.59179826
# METy:
# And think, my life yes with full-bripers:
# For from she down more trunk one what plain as if.
#
# K----------------------------------------
# ----------------------------------------
# Sample Number: 66 	 Loss: 1.58834809
# immerdy;
# Whom arvire, to King roy and here are frais'd
# Of that allow and do work him told my grave.
#
# ----------------------------------------
# ----------------------------------------
# Sample Number: 67 	 Loss: 1.58400790
# f or some may daughter
# We that I mean in prince; quarrire matchord.
# The brooks what was they straight----------------------------------------
# ----------------------------------------
# Sample Number: 68 	 Loss: 1.57995301
# No, Live like a desportions;
# For like a heart, and this Signss?
#
# WARWICK:
# Who set all a blowur Servis----------------------------------------
# ----------------------------------------
# Sample Number: 69 	 Loss: 1.57644930
# Nrours.
#
# SOMERSET:
# Nor then fortunate king, for I stub you
# Call not gaunt to his sim'd wourght our ha----------------------------------------
# ----------------------------------------
# Sample Number: 70 	 Loss: 1.57386010
# ows a bock.
# Why bereft a place the rothers I stook:
# I bid dimment them no tear the bodys,
# And this at----------------------------------------
# ----------------------------------------
# Sample Number: 71 	 Loss: 1.57102944
#
# Lords, it is so not troop so nor shair sink twament worthy gidd,
# My eyes, thanks, and that bark: thu----------------------------------------
# ----------------------------------------
# Sample Number: 72 	 Loss: 1.57154770
# ife
# And I's rine churgefollo. Should; then?
#
# POLIXENES:
# Hercal lack as of stay purbous;
# And what says----------------------------------------
# ----------------------------------------
# Sample Number: 73 	 Loss: 1.57105675
# y:
# So else with the night
# Fst: rest: both; nor that a borner
# Doth a mustice to me: I'll give 'not.
#
# L----------------------------------------
# ----------------------------------------
# Sample Number: 74 	 Loss: 1.56968255
# you have say
# You fight hose is breedon he wish with her, you shall, his blooe;
# To which 'tis thickors----------------------------------------
# ----------------------------------------
# Sample Number: 75 	 Loss: 1.56813348
# doth bring, the dispartion,
# I do buy loous flocks: there's laigues; trail
# Shall reap my worst; them d----------------------------------------
# ----------------------------------------
# Sample Number: 76 	 Loss: 1.56656868
# , by the worm,
# The tongued: wost of your scoosetick
# A blood upon revence care fuol. Shame the grave r----------------------------------------
# ----------------------------------------
# Sample Number: 77 	 Loss: 1.56557850
# INEmer:
# Then more these theist of One. Matter,
# Every andinge's beuse being dabing
# The crowl'dstion, a----------------------------------------
# ----------------------------------------
# Sample Number: 78 	 Loss: 1.56577724
# Pixded a secrang, with nothings, and and oxence
# The pluck savaced has then: premovedation,
# but note t----------------------------------------
# ----------------------------------------
# Sample Number: 79 	 Loss: 1.56530564
#
# Perdase natiling borseous.
#
# PERDITA:
# Harthout and this you have
# Juzs my dangler-soul and you some na----------------------------------------
# ----------------------------------------
# Sample Number: 80 	 Loss: 1.56476091
# ETES:
# I'll your packfor him she was purphich'd.
#
# Shepherd:
# Pity of lie that
# go stay, beseeching frien----------------------------------------
# ----------------------------------------
# Sample Number: 81 	 Loss: 1.56311532
# n'd to the are a confess another mear
# To have not bock the hostst from born, good son sOn; foreswer,
# ----------------------------------------
# ----------------------------------------
# Sample Number: 82 	 Loss: 1.56120099
# your good man of your ding to be, the wive.
# Yours, noble ley, and thus here, what you must
# say thou h----------------------------------------
# ----------------------------------------
# Sample Number: 83 	 Loss: 1.55956311
# :
# The moliets that your shepherd's noble,
# Asfer her in the part; killent bearing
# Affrigh grave help w----------------------------------------
# ----------------------------------------
# Sample Number: 84 	 Loss: 1.55723939
# xes.
#
# Clown:
# The fortunes I am rough and these most dangered
# you now that it done,
# Is it knows the ho----------------------------------------
# ----------------------------------------
# Sample Number: 85 	 Loss: 1.55598737
#
#
# LEONTES:
# If she discovertions a king
# That that way he holy I do voor and
# So thump that Glockes us a----------------------------------------
# ----------------------------------------
# Sample Number: 86 	 Loss: 1.55487725
# S
# You arriver up as the powerwarks, it comes;
# In which have those become with the will of my bussicie----------------------------------------
# ----------------------------------------
# Sample Number: 87 	 Loss: 1.55367450
# er,--
#
# POMPEY:
# Whether well his duken
# Liary are a cherial was own snee-ind child, as
# it is are,--
#
# DU----------------------------------------
# ----------------------------------------
# Sample Number: 88 	 Loss: 1.55085571
# by that at to Vy sun,
# So with thou to her, sir.
#
# LUCIO:
# His to you?
#
# Ask what dead,
# there is at weld.----------------------------------------
# ----------------------------------------
# Sample Number: 89 	 Loss: 1.54911895
# r!
#
# LUCIO:
#
# ANGELO:
# Save your Claudy upon men evil,
# Lookher-teathen are my carry; as I am pray
# To gri----------------------------------------
# ----------------------------------------
# Sample Number: 90 	 Loss: 1.54726535
# ral,
# hut no mine. How evern pray mine:
# Or, give some head believe again bener.
#
# CLAUDIO:
# O, my gods, ----------------------------------------
# ----------------------------------------
# Sample Number: 91 	 Loss: 1.54586961
# e:
# Jurthent; is, men! A sworn, with the misernessmore,
# To come too hunsence viece, greats, for prospe----------------------------------------
# ----------------------------------------
# Sample Number: 92 	 Loss: 1.54387941
# ill tell him dreimishe
# avail to hones of the weary uping hip trick-bace extrossion
# will believing was----------------------------------------
# ----------------------------------------
# Sample Number: 93 	 Loss: 1.54169138
#
# I do many tides.
#
# OUStON:
# It is not alle me! Putswing the many false is a marry
# I shouldst
# fallow. P----------------------------------------
# ----------------------------------------
# Sample Number: 94 	 Loss: 1.53939045
# ss.
#
# ISABELLA:
# Do you may you do morries to tell him but yet in cershie!
# Well duke he water's greats.----------------------------------------
# ----------------------------------------
# Sample Number: 95 	 Loss: 1.53756905
# S O put so talk, and in denied,
# And bring your reasor. First?
# Will who knew's dead end? Clauce, she i----------------------------------------
# ----------------------------------------
# Sample Number: 96 	 Loss: 1.53494951
# hips,
# sudde somewhise with her great spock,
# Than make upon the devil;--and honours,
# Somes as some wit----------------------------------------
# ----------------------------------------
# Sample Number: 97 	 Loss: 1.53361502
# Is repenliny tell no mouth,
# Too husband upon his ponance of Beats is the:
#
# ASCLOY:
# O myt be, and then----------------------------------------
# ----------------------------------------
# Sample Number: 98 	 Loss: 1.53364936
#
#
# SLY:
# O gentle life your bid the tyrant,
# That treat your honour heretive am pliness sal
# Whereo very ----------------------------------------
# ----------------------------------------
# Sample Number: 99 	 Loss: 1.53303684
# of friend,
# I bereebed him you Plange not
# That day I would intenting grief.
#
# TRANIO:
# Mest Claudio, fri----------------------------------------
# ----------------------------------------
# Sample Number: 100 	 Loss: 1.53186312
# ech'ds, as strange'st
# Rehaped possible, knowning in
# By well. If I'll have in Bestant
# Inament for Vero----------------------------------------
# ----------------------------------------
# Sample Number: 101 	 Loss: 1.52999834
# Growhing,
# Your Cack, as the lute but thou arrive and said:
# Masterses is with every fair as my life sh----------------------------------------
# ----------------------------------------
# Sample Number: 102 	 Loss: 1.52876570
# ST,
# Less her wilch, saynve, struck me up, Good 'tis that well:
# I will make freally; buckingeble, wher----------------------------------------
# ----------------------------------------
# Sample Number: 103 	 Loss: 1.52821781
# s on solrow.
#
# BIONDENLO:
# Kissis, I pleased you very like;
# And possessed Lord for'ttings your like me.----------------------------------------
# ----------------------------------------
# Sample Number: 104 	 Loss: 1.52727663
# med but thee feast cumil
# Dame Grumio, thou warms the hopding
# Hure, of thine. Her roouseech and two ch----------------------------------------
# ----------------------------------------
# Sample Number: 105 	 Loss: 1.52606880
# est of my
# disjort an your headed to your dair unpeli.
#
# TRANIO:
# And sir, so he kneat screcely like tha----------------------------------------
# ----------------------------------------
# Sample Number: 106 	 Loss: 1.52451083
# gown: sir, Villor while were,
# my father have her and solroo, you speak fast and did:
# Then you carther----------------------------------------
# ----------------------------------------
# Sample Number: 107 	 Loss: 1.52251397
# ow like my father's.
# Signior Lucentio! how very son's cail! sir.
#
# BIONDELcAd:
# I hote cloan, Vincentio----------------------------------------
# ----------------------------------------
# Sample Number: 108 	 Loss: 1.52038576
# ercy and sad.
#
# KATHARINA:
# Shall she?
#
# PETRUCHIO:
# What, she shokes, by thy house,
# on me that you come ----------------------------------------
# ----------------------------------------
# Sample Number: 109 	 Loss: 1.52066635
# to hear
# Be more parentlifyly boots and
# 'which had within.
# Why, sir, God vile bush!--which was the mis----------------------------------------
# ----------------------------------------
# Sample Number: 110 	 Loss: 1.52076191
# And both and make paeat dearing,--master, mistro, busia,
# That I prison me and lie-take's, father natu----------------------------------------
# ----------------------------------------
# Sample Number: 111 	 Loss: 1.51990070
# d he merchanted
# He arret if e.tith.
#
# ANTONIO:
# He do ranch; was mistakingle rilders.
#
# ANTONIO:
# A fill ----------------------------------------
# Epoch: 1 	 Loss: 1.51951295
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1014/475553379.py in <cell line: 0>()
#      69 # print loss and save weights after every epoch
#      70     print("Epoch: {0} \t Loss: {1:.8f}".format(i_epoch, running_loss/n))
# ---> 71     torch.save(rnn.state_dict(), save_path)
#
# NameError: name 'save_path' is not defined
